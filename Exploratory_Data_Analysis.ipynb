# %% [markdown]
# # Exploratory Data Analysis
#
# * 1 - shooter altitude [ft]
# * 2 - shooter speed [kt]
# * 3 - target altitude [ft]
# * 4 - target speed [kt]
# * 5 - target heading [deg] (the shooter will always be with initial heading 0)
# * 6 - relative position of the target [deg] (angular distance of the target in relation to the "nose" of the shooter)
# * 7 - shooter pitch

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
X = pd.read_csv('data/features50k.csv', delimiter = ' ',header=0)
X.head()
# Out:
#         alt_sht     vel_sht    pit_sht       alt_tgt     vel_tgt     hdg_tgt  \
# 0  36686.369655  588.283896 -40.226314  42422.880668  410.905957  162.575535
# 1  39896.715157  433.645234 -33.281931   1094.641738  591.579604 -149.350321
# 2  41855.661332  413.161620 -40.979502   6543.694811  581.289417 -152.745607
# 3   1063.851564  575.114775 -28.842925   3655.249631  589.917379  120.575422
# 4  36492.712708  402.428233  38.964033   1632.413591  408.603870 -124.513068
#
#      rgt_tgt
# 0 -55.067684
# 1 -48.747876
# 2  50.745556
# 3 -58.899882
# 4 -57.376311

# %%
X.shape
# Out:
# (17515, 7)

# %%
X.describe()
# Out:
#             alt_sht       vel_sht       pit_sht       alt_tgt       vel_tgt  \
# count  17515.000000  17515.000000  17515.000000  17514.000000  17514.000000
# mean   26682.605537    501.375652     -0.520360  22342.428520    491.574437
# std    15741.518975     74.241590     33.391593  16307.185420     73.461090
# min     1000.220192    400.001243    -44.999092   1002.227353    400.000553
# 25%     8243.105391    424.224100    -34.421002   6054.998138    421.782006
# 50%    34020.798485    512.328613     -5.173217  18342.381994    461.393565
# 75%    40473.241283    576.414502     34.151329  39519.440738    572.681958
# max    44999.381948    599.998258     44.998944  44999.423827    599.997962
#
#             hdg_tgt       rgt_tgt
# count  17514.000000  17514.000000
# mean      14.930079     -3.691775
# std      132.292523     44.385803
# min     -179.995942    -59.999625
# 25%     -130.935586    -46.720537
# 50%       69.071841    -20.652924
# 75%      140.619312     44.363279
# ...

# %%
#y = pd.read_csv('data/duck.csv')
y = pd.read_csv('data/duck50k.csv')
y
# Out:
#        maximum_range
# 0          12.890625
# 1           5.859375
# 2          13.671875
# 3           0.078125
# 4           0.078125
# ...              ...
# 49995      10.703125
# 49996       6.328125
# 49997       0.078125
# 49998       0.078125
# 49999       9.140625
#
# [50000 rows x 1 columns]

# %%
y.shape
# Out:
# (50000, 1)

# %%
y.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 50000 entries, 0 to 49999
# Data columns (total 1 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   maximum_range  50000 non-null  float64
# dtypes: float64(1)
# memory usage: 390.8 KB

# %%
y.columns =['max_range']
y
# Out:
#        max_range
# 0      12.890625
# 1       5.859375
# 2      13.671875
# 3       0.078125
# 4       0.078125
# ...          ...
# 49995  10.703125
# 49996   6.328125
# 49997   0.078125
# 49998   0.078125
# 49999   9.140625
#
# [50000 rows x 1 columns]

# %%
df = pd.concat([X,y], join = 'inner', axis=1)
df.to_csv('data/features_and_targets.csv', index=False)

# %%
df.describe().round(2)
# Out:
#         alt_sht   vel_sht   pit_sht   alt_tgt   vel_tgt   hdg_tgt   rgt_tgt  \
# count  17515.00  17515.00  17515.00  17514.00  17514.00  17514.00  17514.00
# mean   26682.61    501.38     -0.52  22342.43    491.57     14.93     -3.69
# std    15741.52     74.24     33.39  16307.19     73.46    132.29     44.39
# min     1000.22    400.00    -45.00   1002.23    400.00   -180.00    -60.00
# 25%     8243.11    424.22    -34.42   6055.00    421.78   -130.94    -46.72
# 50%    34020.80    512.33     -5.17  18342.38    461.39     69.07    -20.65
# 75%    40473.24    576.41     34.15  39519.44    572.68    140.62     44.36
# max    44999.38    600.00     45.00  44999.42    600.00    179.99     60.00
#
#        max_range
# count   17515.00
# mean       13.37
# std        10.67
# min         0.08
# 25%         5.08
# 50%        11.33
# 75%        21.64
# max        39.45

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 17515 entries, 0 to 17514
# Data columns (total 8 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   alt_sht    17515 non-null  float64
#  1   vel_sht    17515 non-null  float64
#  2   pit_sht    17515 non-null  float64
#  3   alt_tgt    17514 non-null  float64
#  4   vel_tgt    17514 non-null  float64
#  5   hdg_tgt    17514 non-null  float64
#  6   rgt_tgt    17514 non-null  float64
#  7   max_range  17515 non-null  float64
# dtypes: float64(8)
# memory usage: 1.1 MB

# %%
df.shape
# Out:
# (17515, 8)

# %%
df.describe().round(2)
# Out:
#         alt_sht   vel_sht   pit_sht   alt_tgt   vel_tgt   hdg_tgt   rgt_tgt  \
# count  17515.00  17515.00  17515.00  17514.00  17514.00  17514.00  17514.00
# mean   26682.61    501.38     -0.52  22342.43    491.57     14.93     -3.69
# std    15741.52     74.24     33.39  16307.19     73.46    132.29     44.39
# min     1000.22    400.00    -45.00   1002.23    400.00   -180.00    -60.00
# 25%     8243.11    424.22    -34.42   6055.00    421.78   -130.94    -46.72
# 50%    34020.80    512.33     -5.17  18342.38    461.39     69.07    -20.65
# 75%    40473.24    576.41     34.15  39519.44    572.68    140.62     44.36
# max    44999.38    600.00     45.00  44999.42    600.00    179.99     60.00
#
#        max_range
# count   17515.00
# mean       13.37
# std        10.67
# min         0.08
# 25%         5.08
# 50%        11.33
# 75%        21.64
# max        39.45

# %%
df.describe()
# Out:
#             alt_sht       vel_sht       pit_sht       alt_tgt       vel_tgt  \
# count  17515.000000  17515.000000  17515.000000  17514.000000  17514.000000
# mean   26682.605537    501.375652     -0.520360  22342.428520    491.574437
# std    15741.518975     74.241590     33.391593  16307.185420     73.461090
# min     1000.220192    400.001243    -44.999092   1002.227353    400.000553
# 25%     8243.105391    424.224100    -34.421002   6054.998138    421.782006
# 50%    34020.798485    512.328613     -5.173217  18342.381994    461.393565
# 75%    40473.241283    576.414502     34.151329  39519.440738    572.681958
# max    44999.381948    599.998258     44.998944  44999.423827    599.997962
#
#             hdg_tgt       rgt_tgt     max_range
# count  17514.000000  17514.000000  17515.000000
# mean      14.930079     -3.691775     13.371739
# std      132.292523     44.385803     10.671219
# min     -179.995942    -59.999625      0.078125
# ...

# %% [raw]
# plt.rcParams.update({'font.size': 15})
#
# plt.figure(figsize=(10,5))
# sns.histplot(df, x="maximum_range",kde=True)
# #plt.hist(df['maximum_range'], bins = 50)
# plt.grid ()
# #plt.legend ([ '$1 \\ Hz$ ', '$2 \\ Hz$ '])
# plt.xlim (1, 45)
# #plt.ylim (0,0.10)
# plt.xlabel('Maximum Range ($nm$)')
# #plt.ylabel('Voltage ($V$)')
# plt.tight_layout()
#
# #plt.savefig ('figures/hist_eps.eps', format ='eps')
# #plt.savefig ('figures/hist_png400.png', format ='png', dpi=400)

# %%
#plt.rc('text ', usetex = True )
plt.rcParams.update({'font.family': 'serif'})
#plt. rcParams . update ({ 'font . size ': 16})

#plt.rcParams["font.family"] = ["Latin Modern Roman"]

# %% [raw]
# sns.set(style="ticks",font_scale=2)
# #sns.set(font="serif")
# plt.rcParams['text.usetex'] = True
# plt.rcParams['text.latex.preamble'] = [r'\usepackage{lmodern}']
# plt.rcParams.update({'font.size': 20})
#
# x = df['max_range'].values
#
# f, (ax_box, ax_hist) = plt.subplots(2, sharex=True,
#                                     gridspec_kw={"height_ratios": (.15, .85)},figsize=(12,5))
#
# sns.boxplot(x, ax=ax_box, color='gray' )
# sns.distplot(x, ax=ax_hist, bins=45, color='gray')
#
#
# plt.xlim(0, 45)
# #plt.ylim (0,0.09)
# plt.xlabel('Maximum Range ($NM$)')
# plt.axvline(x=2/1.852, color='r', linestyle='--', linewidth=3, label='Inferior Threshold Value')
# plt.axvline(x=33.282, color='b', linestyle='--', linewidth=3, label='Superior Threshold Value')
# plt.legend()
# plt.ylabel('Density')
# plt.tight_layout()
# plt.grid()
#
# ax_box.set(yticks=[], xlabel = None)
# sns.despine(ax=ax_hist)
# sns.despine(ax=ax_box, left=True)
#
# #plt.show()
# plt.savefig ('figures/hist_and_box.eps', format ='eps')
# plt.savefig ('figures/hist_and_box.png', format ='png', dpi=400)

# %% [raw]
# # Attempt to change the font
#
# sns.set(style="ticks",font_scale=2)
# #sns.set(font="serif")
# plt.rcParams['text.usetex'] = True
# #plt.rcParams['text.latex.preamble'] = [r'\usepackage{lmodern}']
# plt.rcParams.update({'font.size': 20})
# plt.rcParams.update({'font.family': 'serif'})
#
# x = df['max_range'].values
#
# f, (ax_box, ax_hist) = plt.subplots(2, sharex=True,
#                                     gridspec_kw={"height_ratios": (.15, .85)},figsize=(12,5))
#
# sns.boxplot(x, ax=ax_box, color='gray' )
# sns.distplot(x, ax=ax_hist, bins=45, color='gray')
#
#
# plt.xlim(0, 45)
# #plt.ylim (0,0.09)
# plt.xlabel('Maximum Range ($NM$)')
# plt.axvline(x=2/1.852, color='r', linestyle='--', linewidth=3, label='Inferior Threshold Value')
# plt.axvline(x=33.282, color='b', linestyle='--', linewidth=3, label='Superior Threshold Value')
# plt.legend()
# plt.ylabel('Density')
# plt.tight_layout()
# plt.grid()
#
# ax_box.set(yticks=[], xlabel = None)
# sns.despine(ax=ax_hist)
# sns.despine(ax=ax_box, left=True)
#
# #plt.show()
# plt.savefig ('figures/hist_and_box.eps', format ='eps')
# plt.savefig ('figures/hist_and_box.png', format ='png', dpi=400)

# %% [raw]
# df.describe()

# %%
df = df[df['max_range']>(2/1.852)]
df
# Out:
#             alt_sht     vel_sht    pit_sht       alt_tgt     vel_tgt  \
# 0      36686.369655  588.283896 -40.226314  42422.880668  410.905957
# 1      39896.715157  433.645234 -33.281931   1094.641738  591.579604
# 2      41855.661332  413.161620 -40.979502   6543.694811  581.289417
# 5      41781.803676  589.251762  43.754692  43452.629841  420.800449
# 6       7842.427947  561.416123  40.878973  42523.843746  422.580880
# ...             ...         ...        ...           ...         ...
# 17510   5974.295400  507.319671   4.917168  30575.961515  556.928682
# 17511  14783.887319  513.906490  -4.723287  16901.572939  421.867162
# 17512  11473.602050  456.990362  16.310402  33477.160810  527.232804
# 17513  29255.111075  418.661818 -19.485903  31923.541758  545.352838
# 17514  26708.409584  421.327376 -21.590667           NaN         NaN
#
#           hdg_tgt    rgt_tgt  max_range
# 0      162.575535 -55.067684  12.890625
# 1     -149.350321 -48.747876   5.859375
# ...

# %%
df = df[df['max_range']<33.28]
df.to_csv('data/df50k.csv', index=False)
df
# Out:
#             alt_sht     vel_sht    pit_sht       alt_tgt     vel_tgt  \
# 0      36686.369655  588.283896 -40.226314  42422.880668  410.905957
# 1      39896.715157  433.645234 -33.281931   1094.641738  591.579604
# 2      41855.661332  413.161620 -40.979502   6543.694811  581.289417
# 5      41781.803676  589.251762  43.754692  43452.629841  420.800449
# 6       7842.427947  561.416123  40.878973  42523.843746  422.580880
# ...             ...         ...        ...           ...         ...
# 17510   5974.295400  507.319671   4.917168  30575.961515  556.928682
# 17511  14783.887319  513.906490  -4.723287  16901.572939  421.867162
# 17512  11473.602050  456.990362  16.310402  33477.160810  527.232804
# 17513  29255.111075  418.661818 -19.485903  31923.541758  545.352838
# 17514  26708.409584  421.327376 -21.590667           NaN         NaN
#
#           hdg_tgt    rgt_tgt  max_range
# 0      162.575535 -55.067684  12.890625
# 1     -149.350321 -48.747876   5.859375
# ...

# %%
# Gráfico de Correlação

sns.set(style="ticks",font_scale=1.5)
#sns.set(font="serif")
#plt.rcParams['text.usetex'] = True
plt.rcParams['text.latex.preamble'] = [r'\usepackage{lmodern}']
plt.rcParams.update({'font.size': 17})
plt.rcParams.update({'font.family': 'serif'})

corr_pearson = df.corr(method='pearson')

# Generate a mask for the upper triangle
mask = np.triu(np.ones_like(corr_pearson, dtype=bool))

# Set up the matplotlib figure
f, ax = plt.subplots(figsize=(12, 12))

# Generate a custom diverging colormap
cmap = sns.diverging_palette(20, 230, as_cmap=True)

# Draw the heatmap with the mask and correct aspect ratio
g = sns.heatmap(corr_pearson, mask=mask, cmap=cmap, vmax=.45,vmin=-0.3,center=0,
            square=True, linewidths=.5, cbar_kws={"shrink": .5}, annot=True,
               xticklabels=df.columns[0:-1]);

#g.set_yticklabels(g.get_yticklabels(), rotation = 0, fontsize = 12)

# This sets the yticks "upright" with 0, as opposed to sideways with 90.
plt.xticks(rotation=90)
plt.yticks(rotation=0) 

#sns.set_xticklabels(varLabels, rotation=0, ha='right')
#sns.set_yticklabels(varLabels, rotation=45, va='top')
#plt.show()
plt.savefig ('figures/corr_eps.eps', format ='eps')
plt.savefig ('figures/corr_png400_crop.png', format ='png', dpi=400)
# Out:
# /tmp/ipykernel_124554/485099277.py:6: MatplotlibDeprecationWarning: Support for setting the 'text.latex.preamble' or 'pgf.preamble' rcParam to a list of strings is deprecated since 3.3 and will be removed two minor releases later; set it to a single string instead.
#   plt.rcParams['text.latex.preamble'] = [r'\usepackage{lmodern}']

# %% [raw]
# df_melted = pd.melt(df.iloc[:,:-1],var_name='feature')
# df_melted.head(10)

# %% [raw]
# import psutil

# %% [raw]
# import plotly.express as px
#
# fig = px.box(df_melted, y="value", facet_col="feature", color="feature", boxmode="overlay")
# fig.update_yaxes(matches=None)
#
# for i in range(len(fig["data"])):
#     yaxis_name = 'yaxis' if i == 0 else f'yaxis{i + 1}'
#     fig.layout[yaxis_name].showticklabels = True
#
# fig.update_layout(legend = dict(bgcolor = 'white'))
# fig.update_layout(plot_bgcolor='white')
#
# fig.update_xaxes(showline=True, linewidth=2, linecolor='black')#, mirror=True)
# fig.update_yaxes(showline=True, linewidth=2, linecolor='black')#, mirror=True)
#
# fig.update_xaxes(showgrid=True, gridwidth=1, gridcolor='gray')
# fig.update_yaxes(showgrid=True, gridwidth=1, gridcolor='gray')
# #fig.write_image("figures/boxplot_png400.png")
# #fig.write_image("figures/boxplot_eps.eps")
# #fig.to_image(format="png")
# #fig.savefig ('figures/box_eps.eps', format ='eps')
# #fig.savefig ('figures/box_png400.png', format ='png', dpi=400)

# %% [raw]
# plt.rcParams.update({'font.size': 13})
#
# y = df.loc[:,df.columns].sort_values('max_range', ascending=True).values
# x = np.arange(y.shape[0])
#
# plt.figure(figsize=(15,20))
# for i in range(df.shape[1]):
#     if df.columns[i] == 'max_range':
#         plt.subplot(df.shape[1],1,i+1)
#         plt.plot(x,y[:,i],'r')
#         plt.ylabel(df.columns[i])
#         plt.grid ()
#         plt.xlim (0, len(df))
#         plt.xlabel('Simulation id sorted by the Maximum Range')
#     else:
#         plt.subplot(df.shape[1],1,i+1)
#         plt.plot(x,y[:,i])
#         plt.grid ()
#         plt.xlim (0, len(df))
#         plt.ylabel(df.columns[i])
# plt.savefig ('figures/maximumrangeascending_eps.eps', format ='eps')
# plt.savefig ('figures/maximumrangeascending_png400.png', format ='png', dpi=400)

# %%
sns.set(style="ticks",font_scale=2)
#sns.set(font="serif")
#plt.rcParams['text.usetex'] = True
plt.rcParams['text.latex.preamble'] = [r'\usepackage{lmodern}']
plt.rcParams.update({'font.size': 15})
plt.rcParams.update({'font.family': 'serif'})
#from matplotlib import rc
#rc("text", usetex=False)

corr_pearson = df.corr(method='pearson')

# Generate a mask for the upper triangle
mask = np.triu(np.ones_like(corr_pearson, dtype=bool))

# Set up the matplotlib figure
f, ax = plt.subplots(figsize=(12, 10))

# Generate a custom diverging colormap
cmap = sns.diverging_palette(20, 230, as_cmap=True)

# Draw the heatmap with the mask and correct aspect ratio
g = sns.heatmap(corr_pearson, mask=mask, cmap=cmap, vmax=.45, center=0,
            square=True, linewidths=.5, cbar_kws={"shrink": .5}, annot=True);

#g.set_yticklabels(g.get_yticklabels(), rotation = 0, fontsize = 12)

# This sets the yticks "upright" with 0, as opposed to sideways with 90.
plt.xticks(rotation=90)
plt.yticks(rotation=0) 

#sns.set_xticklabels(varLabels, rotation=0, ha='right')
#sns.set_yticklabels(varLabels, rotation=45, va='top')
#plt.show()
#plt.savefig ('figures/corr_eps.eps', format ='eps')
#plt.savefig ('figures/corr_png400.png', format ='png', dpi=400)
# Out:
# /tmp/ipykernel_124554/3077311463.py:4: MatplotlibDeprecationWarning: Support for setting the 'text.latex.preamble' or 'pgf.preamble' rcParam to a list of strings is deprecated since 3.3 and will be removed two minor releases later; set it to a single string instead.
#   plt.rcParams['text.latex.preamble'] = [r'\usepackage{lmodern}']
# (array([0.5, 1.5, 2.5, 3.5, 4.5, 5.5, 6.5, 7.5]),
#  [Text(0, 0.5, 'alt_sht'),
#   Text(0, 1.5, 'vel_sht'),
#   Text(0, 2.5, 'pit_sht'),
#   Text(0, 3.5, 'alt_tgt'),
#   Text(0, 4.5, 'vel_tgt'),
#   Text(0, 5.5, 'hdg_tgt'),
#   Text(0, 6.5, 'rgt_tgt'),
#   Text(0, 7.5, 'max_range')])

# %%
df.corr()
# Out:
#             alt_sht   vel_sht   pit_sht   alt_tgt   vel_tgt   hdg_tgt  \
# alt_sht    1.000000 -0.031894 -0.296306 -0.004251 -0.051637  0.035310
# vel_sht   -0.031894  1.000000 -0.032795 -0.036534  0.008034  0.014834
# pit_sht   -0.296306 -0.032795  1.000000  0.089456 -0.045446  0.009920
# alt_tgt   -0.004251 -0.036534  0.089456  1.000000  0.086834 -0.010375
# vel_tgt   -0.051637  0.008034 -0.045446  0.086834  1.000000 -0.018946
# hdg_tgt    0.035310  0.014834  0.009920 -0.010375 -0.018946  1.000000
# rgt_tgt   -0.033572  0.007699  0.007975  0.026588  0.024307 -0.009609
# max_range  0.391207 -0.005607  0.418826  0.146218 -0.118014  0.033094
#
#             rgt_tgt  max_range
# alt_sht   -0.033572   0.391207
# vel_sht    0.007699  -0.005607
# pit_sht    0.007975   0.418826
# alt_tgt    0.026588   0.146218
# vel_tgt    0.024307  -0.118014
# hdg_tgt   -0.009609   0.033094
# rgt_tgt    1.000000  -0.074652
# max_range -0.074652   1.000000

# %%
plt.figure(figsize=(15,8))
df.corr()['max_range'].sort_values(ascending=False)[1:].plot(kind='bar');
plt.show()

# %%
corr = pd.DataFrame(df.corr()['max_range'].sort_values(ascending=False))
corr = corr.reset_index()
corr.columns = [['variable','correlation']]
corr.drop(0, axis=0, inplace=True)
corr
# Out:
#   variable correlation
# 1  pit_sht    0.418826
# 2  alt_sht    0.391207
# 3  alt_tgt    0.146218
# 4  hdg_tgt    0.033094
# 5  vel_sht   -0.005607
# 6  rgt_tgt   -0.074652
# 7  vel_tgt   -0.118014

# %% [markdown]
# ### Outliers

# %%
from numpy import percentile

outliers_cols = df.columns
outliers = {}
outliers_removed = {}
for idx, col in enumerate(outliers_cols):
    # calculate interquartile range
    data = df[col]
    q25, q75 = percentile(data, 25), percentile(data, 75)
    iqr = q75 - q25
    print(f'Variable ({idx+1}): {col}\nPercentiles: 25th = {q25:.3f}, 75th = { q75:.3f}, IQR = {iqr:.3f}')
    # calculate the outlier cutoff
    k = 1.5
    cut_off = iqr * k
    lower, upper = q25 - cut_off, q75 + cut_off
    # identify outliers
    outliers[col] = [x for x in data if x < lower or x > upper]
    print(f'Identified outliers: {len(outliers[col])}')
    # remove outliers
    outliers_removed[col] = [x for x in data if x >= lower and x <= upper]
    print(f'Non-outlier observations: {len(outliers_removed[col])}\n')
# Out:
# Variable (1): alt_sht
# Percentiles: 25th = 18049.739, 75th = 40980.809, IQR = 22931.070
# Identified outliers: 0
# Non-outlier observations: 13434
#
# Variable (2): vel_sht
# Percentiles: 25th = 424.360, 75th = 574.266, IQR = 149.907
# Identified outliers: 0
# Non-outlier observations: 13434
#
# Variable (3): pit_sht
# Percentiles: 25th = -33.218, 75th = 33.835, IQR = 67.052
# Identified outliers: 0
# Non-outlier observations: 13434
#
# Variable (4): alt_tgt
# Percentiles: 25th = nan, 75th = nan, IQR = nan
# Identified outliers: 0
# Non-outlier observations: 0
#
# Variable (5): vel_tgt
# Percentiles: 25th = nan, 75th = nan, IQR = nan
# Identified outliers: 0
# Non-outlier observations: 0
#
# Variable (6): hdg_tgt
# Percentiles: 25th = nan, 75th = nan, IQR = nan
# Identified outliers: 0
# Non-outlier observations: 0
#
# Variable (7): rgt_tgt
# Percentiles: 25th = nan, 75th = nan, IQR = nan
# Identified outliers: 0
# Non-outlier observations: 0
#
# Variable (8): max_range
# ...

# %%
y = df.loc[:,df.columns].sort_values('max_range', ascending=True).values
x = np.arange(y.shape[0])

plt.figure(figsize=(15,15))
for i in range(df.shape[1]):
    if df.columns[i] == 'maximum_range':
        plt.subplot(df.shape[1],1,i+1)
        plt.plot(x,y[:,i],'r')
        plt.ylabel(df.columns[i])            
    else:   
        plt.subplot(df.shape[1],1,i+1)
        plt.plot(x,y[:,i])
        plt.ylabel(df.columns[i])
